# %%
import torch
from torch import nn

# Input: Temperature in °C
X1 = torch.tensor([[10]]) 
# Actual value: Temperature °F
y1 = torch.tensor([[50]]) 

# Input: Temperature in °C
X2 = torch.tensor([[37.78]]) 
# Actual value: Temperature °F
y2 = torch.tensor([[100.0]]) 

model = nn.Linear(1, 1)

# TODO: Convert all tensors above to dtype=torch.float32
# TODO: Create a loss function (MSELoss)
# TODO: Create an optimizer (SGD with lr=0.001)

print(model.bias)

# TODO: Perform one training pass:
# - zero gradients
# - forward pass
# - calculate loss
# - backward pass
# - optimizer step

print(model.bias)

y1_pred = model(X1)
print("y1_pred =", y1_pred)
