# %%
import torch
from torch import nn

device = torch.device("cpu")
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.mps.is_available():
    device = torch.device("mps")

print("Running on device:", device)

a = torch.tensor([5, 7], device=device, dtype=torch.float32)
b = torch.tensor([3, 4], device=device)

print(a + b)

# TODO: Define a simple model with one Linear layer and move it to the chosen device

# TODO: Run the model on `a.reshape(1, 2)`

# TODO: Apply softmax to the outputs

# TODO: Print the probabilities
