# %%
import torch
from torch import nn

# TODO: Select device (CPU, CUDA, or MPS depending on availability)

# TODO: Print the device being used

# TODO: Create tensor `a` directly on the chosen device

# TODO: Create tensor `b` on CPU and then move it to the chosen device

# TODO: Print the devices of both tensors

# TODO: Print the result of adding them together
