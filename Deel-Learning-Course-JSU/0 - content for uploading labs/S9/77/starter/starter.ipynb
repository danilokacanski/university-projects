# %%
import torch
from torch import nn

import torchvision.datasets as datasets

# %%
mnist_train = datasets.MNIST(root='./data', download=True, train=True)
# TODO: Print the 3rd training sample (index 2) to see its (image, label) tuple

# %%
# TODO: Access only the image part of that sample (mnist_train[2][0])

# %%
import numpy as np
# TODO: Convert that image to a NumPy array and print it

# %%
mnist_test = datasets.MNIST(root='./data', download=True, train=False)
# TODO: Print the test dataset object to inspect its size/metadata
