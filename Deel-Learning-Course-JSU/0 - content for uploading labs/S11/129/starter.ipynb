# %%
import torch

# Load the saved fully-connected head weights
weights = torch.load("fc_model_3.pth", weights_only=True)
print(weights)

# TODO: Load the checkpoint onto CPU by adding map_location="cpu"

# TODO: Re-save the (CPU) weights to a new file name (e.g., "fc_mpdel_3.pth")
