# %%
import torch

# Load the saved fully-connected head weights
weights = torch.load("fc_model_3.pth", weights_only=True, map_location="cpu")

# Re-save the (CPU) weights to a new file name (e.g., "fc_mpdel_3.pth")
torch.save(weights, "fc_model_3.pth")

print(weights)
# Out:
# OrderedDict({'0.weight': tensor([[-0.0132, -0.0037,  0.0013,  ..., -0.0115,  0.0113, -0.0172],
#         [-0.0051,  0.0158, -0.0154,  ..., -0.0108,  0.0055, -0.0163],
#         [ 0.0004, -0.0030,  0.0031,  ..., -0.0042, -0.0047, -0.0005],
#         ...,
#         [ 0.0145, -0.0118, -0.0136,  ..., -0.0032,  0.0050, -0.0150],
#         [ 0.0099, -0.0059, -0.0009,  ..., -0.0157, -0.0018,  0.0133],
#         [ 0.0018,  0.0150,  0.0035,  ...,  0.0064, -0.0027,  0.0098]]), '0.bias': tensor([-0.0044, -0.0003,  0.0023,  ...,  0.0125, -0.0067,  0.0151]), '2.weight': tensor([[ 0.0137,  0.0120, -0.0263,  ...,  0.0200,  0.0087,  0.0218]]), '2.bias': tensor([-0.0208])})
