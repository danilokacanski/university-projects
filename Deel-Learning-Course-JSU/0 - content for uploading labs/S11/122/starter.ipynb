# %%
import sys
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import random_split, DataLoader

preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# TODO: Load the dataset using torchvision.datasets.ImageFolder with root="../images"

# TODO: Split the dataset into training and validation sets (e.g., 80/20)

# TODO: Create DataLoaders for both training and validation sets
