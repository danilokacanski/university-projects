# %%
import sys
import torch
from torch import nn
import pandas as pd

df = pd.read_csv("loan_data.csv")
df = df[["loan_status", "person_income", "loan_intent", "loan_percent_income", "credit_score"]]

# TODO: One-hot encode the "loan_intent" column using pd.get_dummies

# TODO: Print the dataframe columns

# TODO: Create target tensor y from "loan_status"
# Hint: reshape it to (-1, 1)

# TODO: Drop "loan_status" to prepare features

# TODO: Convert features to float32 and check dtype

# TODO: Create tensor X from features and print it
