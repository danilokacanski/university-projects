# %%
import sys
import torch
from torch import nn
import pandas as pd

df = pd.read_csv("loan_data.csv")
df = df[["loan_status", "person_income", "loan_intent", "loan_percent_income", "credit_score"]]
df = pd.get_dummies(df, columns=["loan_intent"])

# Create target tensor y from "loan_status"
y = torch.tensor(df["loan_status"], dtype=torch.float32)\
    .reshape((-1, 1))

# Prepare features
X_data = df.drop("loan_status", axis=1).astype('float32').values
X = torch.tensor(X_data, dtype=torch.float32)

# TODO: Normalize X by subtracting mean and dividing by std

# TODO: Build a nn.Sequential model with layers:
#   Linear(9, 32) -> ReLU -> Linear(32, 16) -> ReLU -> Linear(16, 1)

# TODO: Create BCEWithLogitsLoss loss function

# TODO: Create Adam optimizer with lr=0.0001

# TODO: Train the model for 100 epochs in batches of 32

# TODO: After training, evaluate model accuracy on X
