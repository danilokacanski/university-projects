# %%
import pandas as pd

df = pd.DataFrame({
    "loan_intent":["PERSONAL", "EDUCATION"],
    "person_income": [30000, 50000]
})

# TODO: One-hot encode the column `loan_intent` using pd.get_dummies
# TODO: Convert all values to float32 with .astype("float32")

# TODO: Show the head of the dataframe

# %%
df.values

# %%
import torch

# TODO: Convert the dataframe values to a torch.tensor of dtype float32

# TODO: Print the tensor
