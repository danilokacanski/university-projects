# %%
import pandas as pd

df = pd.read_csv("loan_data.csv")

# TODO: Select only the columns:
#   "loan_status", "person_income", "loan_intent",
#   "loan_percent_income", "credit_score"

# TODO: Show the first few rows of the filtered dataframe

# %%
# TODO: Group by "loan_status" and aggregate:
#   - person_income: mean, min, max
#   - credit_score: mean, min, max
#   - loan_percent_income: mean, min, max

# %%
# TODO: Group by "loan_intent" and aggregate:
#   - loan_status: mean
