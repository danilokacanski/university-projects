# %%
import sys
import torch
from torch import nn
import pandas as pd

df = pd.read_csv("../starter/student_exam_data.csv")

X = torch.tensor(
    df[["Study Hours", "Previous Exam Score"]].values,
    dtype=torch.float32
)
y = torch.tensor(df["Pass/Fail"], dtype=torch.float32)\
    .reshape((-1, 1))

hidden_model = nn.Linear(2, 10)
output_model = nn.Linear(10, 1)
loss_fn = torch.nn.BCEWithLogitsLoss()
parameters = list(hidden_model.parameters()) + list(output_model.parameters())
optimizer = torch.optim.SGD(parameters, lr=0.005)

for i in range(0, 500000):
    optimizer.zero_grad()
    outputs = hidden_model(X)
    outputs = nn.functional.sigmoid(outputs)
    outputs = output_model(outputs)
    loss = loss_fn(outputs, y)
    loss.backward()
    optimizer.step()

    if i % 10000 == 0:
        print(loss)

# Set both hidden_model and output_model to eval mode
hidden_model.eval()
output_model.eval()

# Under torch.no_grad(), run X through hidden_model → sigmoid → output_model
with torch.no_grad():
    outputs = hidden_model(X)
    outputs = nn.functional.sigmoid(outputs)
    outputs = output_model(outputs)

    # Apply sigmoid to final outputs, threshold at 0.5 to get y_pred
    y_pred = nn.functional.sigmoid(outputs) > 0.5

    # Compare y_pred to y and print the mean accuracy
    y_pred_correct = y_pred.type(torch.float32) == y
    print(y_pred_correct.type(torch.float32).mean())
# Out:
# tensor(0.6828, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5095, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3562, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3062, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2607, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2414, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2031, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.1841, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.1634, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.1463, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.1317, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.1192, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.1083, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0987, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0904, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0831, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0768, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0714, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0666, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0624, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0587, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0554, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0524, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0497, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0472, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0450, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0429, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0410, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0393, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0376, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0361, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0347, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0334, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0323, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0315, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0308, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0302, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0296, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0290, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0285, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0279, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0274, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0270, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0265, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0261, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0256, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0252, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0248, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0245, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0241, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.)
