# %%
import pandas as pd

df = pd.read_csv("../starter/student_exam_data.csv")
# Show the first few rows of the DataFrame
df.head()
# Out:
#    Study Hours  Previous Exam Score  Pass/Fail
# 0     4.370861            81.889703          0
# 1     9.556429            72.165782          1
# 2     7.587945            58.571657          0
# 3     6.387926            88.827701          1
# 4     2.404168            81.083870          0

# %%
import matplotlib.pyplot as plt

# Create a scatter plot of Study Hours vs Previous Exam Score
# and color the points by Pass/Fail
plt.scatter(df["Study Hours"], df["Previous Exam Score"], c=df["Pass/Fail"])
plt.show()
