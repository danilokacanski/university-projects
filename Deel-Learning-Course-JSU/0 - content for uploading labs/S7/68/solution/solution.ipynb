# %%
import sys
import torch
from torch import nn
import pandas as pd

df = pd.read_csv("../starter/student_exam_data.csv")

X = torch.tensor(
    df[["Study Hours", "Previous Exam Score"]].values,
    dtype=torch.float32
)
y = torch.tensor(df["Pass/Fail"], dtype=torch.float32)\
    .reshape((-1, 1))

model = nn.Sequential(
    nn.Linear(2, 10),
    # Change activation to nn.ReLU()
    nn.ReLU(),
    nn.Linear(10, 1)
)
print(model)

loss_fn = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.005)

for i in range(0, 500000):
    optimizer.zero_grad()
    outputs = model(X)
    loss = loss_fn(outputs, y)
    loss.backward()
    optimizer.step()

    if i % 10000 == 0:
        print(loss)

model.eval()
with torch.no_grad():
    outputs = model(X)
    y_pred = nn.functional.sigmoid(outputs) > 0.5
    y_pred_correct = y_pred.type(torch.float32) == y
    print(y_pred_correct.type(torch.float32).mean())
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=10, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=10, out_features=1, bias=True)
# )
# tensor(6.2103, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2580, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2075, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.1631, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.1433, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.1174, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0821, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0694, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.1048, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0641, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0499, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0466, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0435, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0419, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0388, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0362, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0344, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0429, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0314, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0302, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0324, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0281, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0274, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0261, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0251, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0241, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0235, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0228, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0223, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0218, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0210, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0224, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0277, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0278, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0257, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0254, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0242, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0283, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0316, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0218, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0217, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0203, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0284, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0201, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0191, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0185, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0179, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0174, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0170, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.0168, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.)
