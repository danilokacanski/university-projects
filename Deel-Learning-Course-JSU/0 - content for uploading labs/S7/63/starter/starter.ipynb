# %%
import torch
from torch import nn
import pandas as pd

df = pd.read_csv("student_exam_data.csv")

# TODO: Create feature tensor X using "Study Hours" and "Previous Exam Score"
# TODO: Create target tensor y using "Pass/Fail", reshaped to (-1, 1)

# TODO: Define a Linear model with 2 inputs and 1 output
# TODO: Define a BCEWithLogitsLoss loss function
# TODO: Define an SGD optimizer with learning rate 0.005

# TODO: Train the model for 500,000 iterations
#       - zero gradients
#       - forward pass
#       - compute loss
#       - backward pass
#       - optimizer step
#       Print loss every 10,000 iterations

# TODO: Put the model in eval mode and compute predictions
#       - apply sigmoid and threshold at 0.5
#       - compare to true labels
#       - print mean accuracy
