# %%
import torch
from torch import nn

X = torch.tensor([
    [10.0],
    [38.0],
    [100.0],
    [150.0]
])

model = nn.Linear(1, 1)

# TODO: Set the bias of the model to 32.0


# TODO: Set the weight of the model to 1.8


# TODO: Print the bias of the model


# TODO: Print the weight of the model


# TODO: Perform prediction with the model and print y_pred
