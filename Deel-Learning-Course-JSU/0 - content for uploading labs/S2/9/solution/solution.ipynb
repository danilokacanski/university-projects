# %%
import torch

# Fill in the bias tensor
b = torch.tensor(32)

# Fill in the weight tensor
w1 = torch.tensor(1.8)

# Fill in the input tensor
X1 = torch.tensor(10)

# Calculate the output
y_pred = 1 * b + X1 * w1

print(y_pred)
# Out:
# tensor(50.)
