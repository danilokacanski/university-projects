# %%
import torch

b = torch.tensor(32)
w1 = torch.tensor(1.8)
X1 = torch.tensor([10, 38, 100, 150])

y_pred = 1 * b + X1 * w1

# Print the shape of b
print(b.shape)

# Print the shape of X1
print(X1.shape)

# Print the size of b
print(b.size())

# Print the size of X1
print(X1.size())

# Print the second value from y_pred 
print(y_pred[1].item())
# Out:
# torch.Size([])
# torch.Size([4])
# torch.Size([])
# torch.Size([4])
# 100.4000015258789
