# %%
import torch
from torch import nn

# Add dtype=torch.float32 when creating X
X = torch.tensor([
    [10],
    [38],
    [100],
    [150]
], dtype=torch.float32)
# Print the dtype of X
print("X.dtype =", X.dtype)

# Print the shape of X
print("X.shape =", X.shape)

# Print the tensor X
print("X =", X)
# Out:
# X.dtype = torch.float32
# X.shape = torch.Size([4, 1])
# X = tensor([[ 10.],
#         [ 38.],
#         [100.],
#         [150.]])
