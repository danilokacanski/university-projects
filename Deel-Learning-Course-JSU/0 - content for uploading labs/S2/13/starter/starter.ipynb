# %%
import torch
from torch import nn

# TODO: Add dtype=torch.float32 when creating X
X = torch.tensor([
    [10],
    [38],
    [100],
    [150]
])
# TODO: Print the dtype of X

# TODO: Print the shape of X

# TODO: Print the tensor X
