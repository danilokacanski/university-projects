# %%
import torch
from torch import nn
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

df = pd.read_csv("SMSSpamCollection",
                 sep="\t",
                 names=["type", "message"])

df["spam"] = df["type"] == "spam"
df.drop("type", axis=1, inplace=True)

cv = CountVectorizer(max_features=1000)
messages = cv.fit_transform(df["message"])

X = torch.tensor(messages.todense(), dtype=torch.float32)
y = torch.tensor(df["spam"], dtype=torch.float32).reshape((-1, 1))

model = nn.Linear(1000, 1)

# TODO: Define the loss function using MSELoss

# TODO: Define the optimizer using SGD with learning rate 0.001


# TODO: Train the model for 10000 iterations:
#   - zero gradients
#   - forward pass
#   - compute loss
#   - backward pass
#   - optimizer step
#   Print the loss every 100 iterations

# TODO: Switch the model to evaluation mode and:
#   - make predictions on X
#   - print predictions
#   - print minimum prediction
#   - print maximum prediction
