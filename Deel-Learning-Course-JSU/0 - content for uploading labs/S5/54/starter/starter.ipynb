# %%
from transformers import BartTokenizer, BartModel
import torch
from torch import nn

messages = [
    "We have release a new product, do you want to buy it?",
    "Winner! Great deal, call us to get this product for free",
    "Tomorrow is my birthday, do you come to the party?",
]

# TODO: Load the tokenizer "facebook/bart-base"

# TODO: Tokenize `messages` with:
#  - padding=True
#  - max_length=512
#  - truncation=True
#  - return_tensors="pt"

# TODO: Load the BART model "facebook/bart-base"

with torch.no_grad():
    # TODO: Put the model in eval mode

    # TODO: Print the tokenized output object `out`

    # TODO: Run the model with input_ids and attention_mask

    # TODO: Take mean over sequence dimension to get embeddings

    # TODO: Print embeddings.shape and the first row embeddings[0, :]
