# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

df = pd.read_csv("SMSSpamCollection",
                 sep="\t",
                 names=["type", "message"])

df["spam"] = df["type"] == "spam"
df.drop("type", axis=1, inplace=True)

# TODO: Create a CountVectorizer with max_features=1000

# TODO: Fit it on df["message"] and transform into messages

# TODO: Print the first row of messages

# TODO: Print the feature name at index 888

# %%
cv = CountVectorizer(max_features=6)
documents = [
    "Hello world. Today is amazing. Hello hello",
    "Hello mars, today is perfect"
]

# TODO: Fit the vectorizer on documents

# TODO: Print the feature names

# TODO: Transform documents and print the dense output
