# %%
import matplotlib.pyplot as plt
import torch
from torch import nn

# %%
nn.functional.sigmoid(torch.tensor([-100, 2, 3]))

# %%
# TODO: Create X as values from -5 to 5 with step 0.1

# TODO: Apply the sigmoid function to X and store in y

# %%
# TODO: Plot X against y
