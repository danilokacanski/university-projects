# %%
import pandas as pd

df = pd.read_csv("SMSSpamCollection", sep="\t", names=["type", "message"])

# TODO: Create a boolean column 'spam' where value is True if type == "spam"
# df["spam"] = ...

# TODO: Drop the original 'type' column
# df.drop(...)

# TODO: Show the first few rows
# df.head()

# %%
# TODO: Print the number of SPAM messages
# print(...)

# %%
# TODO: Print the number of non-SPAM messages
# print(...)
