# %%
import pandas as pd

df = pd.read_csv("used_cars.csv")
df.head()

# %%
price = df["price"]

# TODO: Remove the "$" character from price (string replace)


# TODO: Remove commas from price (string replace)


# TODO: Convert price to integers (astype)


df["price"] = price
df.head()

# %%
# TODO: Print the mean of the 'price' column

# %%
# TODO: Create a DataFrame df_hyundai with rows where brand == "Hyundai"


# TODO: Print the mean price of df_hyundai


# TODO: Create a DataFrame df_ford with rows where brand == "Ford"


# TODO: Print the mean price of df_ford

# %%
# TODO: Create one-hot encodings for the 'brand' column using pd.get_dummies(df["brand"])

# %%
import numpy as np

# TODO: Print the correlation coefficients between 'model_year' and 'price' using np.corrcoef

# %%
import matplotlib.pyplot as plt

df_filtered = df[df["price"] < 300000]

# TODO: Create a scatter plot of model_year (x) vs price (y) using plt.scatter
