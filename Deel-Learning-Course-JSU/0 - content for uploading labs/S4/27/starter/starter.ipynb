# %%
import pandas as pd

df = pd.read_csv("used_cars.csv")

# TODO: Display the first few rows of the DataFrame

# %%
# TODO: Print the number of rows in df


# TODO: Print the shape of df (rows, columns)

# %%
# TODO: Plot a histogram of the 'model_year' column with 20 bins

# %%
# TODO: Print the mean of the 'model_year' column


# TODO: Print the minimum of the 'model_year' column


# TODO: Print the maximum of the 'model_year' column

# %%
# Clean the 'price' column and analyze it
price = df["price"]

# TODO: Remove the '$' character from price (string replace)


# TODO: Remove commas from price (string replace)


# TODO: Convert price to integers (astype)


# TODO: Print only prices less than 300000


# TODO: Plot a histogram of prices less than 300000
