# %%
import pandas as pd

df = pd.read_csv("used_cars.csv")
df.head()

# %%
price = df["price"]
price = price.str.replace("$", "")
price = price.str.replace(",", "")
price = price.astype(int)
print(price)

# %%
# TODO: Calculate the age of each car as max(model_year) - model_year


# TODO: Print the age column

# %%
# TODO: Clean the 'milage' column:
# - remove commas
# - remove " mi."


# TODO: Convert the cleaned 'milage' column to integers


# TODO: Print the cleaned milage column
