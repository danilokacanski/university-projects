# %%
import gradio as gr
# TODO: Import PIL.Image so we can convert the uploaded NumPy array to a PIL image
# from PIL import Image

# TODO: Change the second parameter to accept image pixels (a NumPy array) instead of text
# TODO: Print the Python type and shape of the uploaded image for inspection
# TODO: Convert the NumPy array to a PIL image with Image.fromarray(...)
# TODO: Keep the return as a simple greeting string for now
def greet(name, message):
    return "Hello " + name + "! " + message

demo = gr.Interface(
    fn=greet,
    inputs=[
        gr.Text(label="Please enter your name:"),
        # TODO: Replace this TextArea with an Image uploader: gr.Image()
        gr.TextArea(label="Please enter your message:")
    ],
    # TODO: Keep a single text output for the greeting
    outputs=gr.Text(label="Output:")
)
demo.launch()
