# %% [markdown]
# Idea is to forecast 1-6 hours til the 48 hours with lookback from 7 days to 30 days.

# %%
import os
import math
import time
from pathlib import Path
from datetime import timedelta

import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader

from transformers import PatchTSTConfig, PatchTSTForPrediction  # HF time-series
# Docs for PatchTST (shapes, classes, outputs): https://huggingface.co/docs/transformers/en/model_doc/patchtst

# %%
df = pd.read_csv('data/combined_hourly_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49363 entries, 0 to 49362
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                49363 non-null  object
#  1   open                     49363 non-null  float64
#  2   high                     49363 non-null  float64
#  3   low                      49363 non-null  float64
#  4   close                    49363 non-null  float64
#  5   volume                   49363 non-null  float64
#  6   block_blocks_count       49363 non-null  float64
#  7   block_total_size_bytes   49363 non-null  float64
#  8   block_total_txs          49363 non-null  float64
#  9   block_avg_txs_per_block  49363 non-null  float64
#  10  block_avg_block_size     49363 non-null  float64
#  11  Bitcoin                  49363 non-null  float64
#  12  BTC                      49363 non-null  float64
# ...

# %%
df[['timestamp','close']].to_csv('./1st try/data/btc_close.csv',index=False)
