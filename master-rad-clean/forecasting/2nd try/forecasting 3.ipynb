# %%
import pandas as pd

# %%
df = pd.read_csv('data/strategies_5cls_2h_numeric.csv')
df = df.drop(columns=["fwd_ret_2h", "class", "action_pos"],errors="ignore")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49277 entries, 0 to 49276
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                49277 non-null  object
#  1   close                    49277 non-null  float64
#  2   ret_1h                   49277 non-null  float64
#  3   ret_2h                   49277 non-null  float64
#  4   ret_4h                   49277 non-null  float64
#  5   ret_12h                  49277 non-null  float64
#  6   ret_24h                  49277 non-null  float64
#  7   roll_mean_ret_6h         49277 non-null  float64
#  8   roll_std_ret_6h          49277 non-null  float64
#  9   roll_mean_ret_12h        49277 non-null  float64
#  10  roll_std_ret_12h         49277 non-null  float64
#  11  roll_mean_ret_24h        49277 non-null  float64
#  12  roll_std_ret_24h         49277 non-null  float64
# ...

# %%
X = df.drop(columns=["timestamp", "action_note", "class_id"])
y = df["class_id"]

print("Feature shape:", X.shape)
print("Target shape:", y.shape)
print("Classes:", y.unique())
# Out:
# Feature shape: (49277, 42)
# Target shape: (49277,)
# Classes: [2 3 1 4 0]
